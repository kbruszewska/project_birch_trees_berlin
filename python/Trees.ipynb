# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
# There are two parts of the district (two subdistricts): Friedrichshain and Kreuzberg. 
# Data sets are separetly for them and separetly for each year.

# %% [markdown]
# #### Steps to prepare data set with cut down trees:
# - Importing each file separetly.
# - Change names of columns (rename columns)
# - Add a column with the subdistrict name (str)
#     - "F" for Friedrichshain and "K" for Kreuzberg
# - Additional column with year when the tree was cut down (int)
# - From column "gefällt" which means if the tree was cut down, substract the info about if the tree was cut down.
#     - Dropping rows with null vlaues (meaning the tree was not cut down)
#     - Dropping rows with "nein" (meaining the tree was not cut down)
#
# - Output: 14 separete files with trees devided in different years and subdistricts.

# %% [markdown]
# ### Trees in subdistrict Kreuzberg

# %%
#2022

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/2022_faellliste_kreuzberg.xlsx')
df
# Out:
#     notwendige Baumfällungen im Ortsteil Kreuzberg 2022 Unnamed: 1  \
# 0                                                  NaN         NaN
# 1                                               Stand:         NaN
# 2                                  2023-01-01 00:00:00         NaN
# 3                                                  NaN         NaN
# 4                                             Standort     Baumnr.
# ..                                                 ...         ...
# 511                                     Yorckstr. 4-11          33
# 512                                     Yorckstr. 4-11          36
# 513                                     Yorckstr. 4-11          42
# 514                                        Yorckstraße          75
# 515                                        Yorckstraße         170
#
#                         Unnamed: 2  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                          Baumart
# ..                             ...
# 511  Italienische Pyramiden-Pappel
# 512  Italienische Pyramiden-Pappel
# 513        Berliner Lorbeer-Pappel
# 514                          Linde
# 515                   Silber-Linde
#
#                                             Unnamed: 3    Unnamed: 4
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4    Ergebnis der Begutachtung/ Notwendigkeit der F...  2022 gefällt
# ..                                                 ...           ...
# 511              gefährdete Bruch- und Standsicherheit            ja
# 512              gefährdete Bruch- und Standsicherheit           NaN
# 513              gefährdete Bruch- und Standsicherheit           NaN
# 514              gefährdete Bruch- und Standsicherheit           NaN
# 515              gefährdete Bruch- und Standsicherheit           NaN
#
# [516 rows x 5 columns]

# %%
def clean_data_k_2022(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Kreuzberg 2022':'Standort',\
                            'Unnamed: 1':'Baumnr',\
                            'Unnamed: 2':'Baumart', \
                            'Unnamed: 3':'Fällgrund',\
                            'Unnamed: 4':'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_k_2022(df, 2022, "K")

# %%
df
# Out:
#                        Standort Baumnr                          Baumart  \
# 0       Adalbertstr. 95A, Spiel      3                       Vogelbeere
# 1           Alexandrinenstr. 12     79                     Blut-Pflaume
# 2           Alexandrinenstr. 12     92                     Silber-Ahorn
# 3           Alexandrinenstr. 12    102                  Trauben-Kirsche
# 4           Alexandrinenstr. 12   18/5                            Weide
# ..                          ...    ...                              ...
# 442               Wiener Straße    195         Japanische Blütenkirsche
# 443               Wiener Straße    232  Japanische Zierkirsche 'Kanzan'
# 444  Wrangelstr. 10, Spiel Bolz      6                          Robinie
# 445               Wrangelstraße     48                      Spitz-Ahorn
# 446              Yorckstr. 4-11     33    Italienische Pyramiden-Pappel
#
#                                  Fällgrund gefällt  Jahr Ortsteil
# 0                  absterbend/ abgestorben      ja  2022        K
# 1    gefährdete Bruch- und Standsicherheit      ja  2022        K
# 2    gefährdete Bruch- und Standsicherheit      ja  2022        K
# 3    gefährdete Bruch- und Standsicherheit      ja  2022        K
# 4                  absterbend/ abgestorben      ja  2022        K
# ..                                     ...     ...   ...      ...
# 442  gefährdete Bruch- und Standsicherheit      ja  2022        K
# 443  gefährdete Bruch- und Standsicherheit      ja  2022        K
# 444  gefährdete Bruch- und Standsicherheit      ja  2022        K
# 445                absterbend/ abgestorben      ja  2022        K
# 446  gefährdete Bruch- und Standsicherheit      ja  2022        K
#
# [447 rows x 7 columns]

# %%
df["gefällt"].value_counts()
# Out:
# gefällt
# ja    447
# Name: count, dtype: int64

# %%
# Here I have encounter the problem with encoding special characters, like öäü so I have decided to export file as .xlsx first

df.to_excel('2022_kreuz_cutdown.xlsx', index=False)

# %%
#2023

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/faellliste-kreuzberg-stand-311223.xlsx')
df
# Out:
#     notwendige Baumfällungen im Ortsteil Kreuzberg 2023 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN         NaN        NaN
# 1                                                  NaN         NaN        NaN
# 2                                                  NaN         NaN        NaN
# 3                                                  NaN         NaN        NaN
# 4                                             Standort     Baumnr.    Baumart
# ..                                                 ...         ...        ...
# 478                                                NaN         NaN        NaN
# 479                                                NaN         NaN        NaN
# 480                                                NaN         NaN        NaN
# 481                                                NaN         NaN        NaN
# 482                                               Ende         NaN        NaN
#
#                                             Unnamed: 3    Unnamed: 4
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4    Ergebnis der Begutachtung/ Notwendigkeit der F...  2023 gefällt
# ..                                                 ...           ...
# 478                                                NaN           NaN
# 479                                                NaN           NaN
# 480                                                NaN           NaN
# 481                                                NaN           NaN
# 482                                                NaN           NaN
#
# [483 rows x 5 columns]

# %%
def clean_data_k_2023(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Kreuzberg 2023':'Standort',\
                            'Unnamed: 1':'Baumnr',\
                            'Unnamed: 2':'Baumart', \
                            'Unnamed: 3':'Fällgrund',\
                            'Unnamed: 4':'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_k_2023(df, 2023, "K")

# %%
df
# Out:
#                                            Standort Baumnr  \
# 0                               Alexandrinenstr. 12     80
# 1                               Alexandrinenstr. 12   89/4
# 2    Alexandrinenstr./ Prinzenstr. am Landwehrkanal     19
# 3    Alexandrinenstr./ Prinzenstr. am Landwehrkanal   49/1
# 4                                Alexandrinenstraße  269/2
# ..                                              ...    ...
# 276                                     Yorckstraße    136
# 277                                     Yorckstraße    137
# 278                                     Yorckstraße    138
# 279                                     Yorckstraße    170
# 280                            Züllichauer Str. 1-7     15
#
#                      Baumart                              Fällgrund gefällt  \
# 0                  Rotfichte  gefährdete Bruch- und Standsicherheit      ja
# 1               Eschen-Ahorn                   Wuchsraumregulierung      ja
# 2                  Hainbuche                absterbend/ abgestorben      ja
# 3    Berg-Ahorn, Weiss-Ahorn                absterbend/ abgestorben      ja
# 4                  Berg-Ulme                absterbend/ abgestorben      ja
# ..                       ...                                    ...     ...
# 276             Silber-Linde                absterbend/ abgestorben      ja
# 277                    Linde                absterbend/ abgestorben      ja
# 278             Kaiser-Linde                absterbend/ abgestorben      ja
# 279             Silber-Linde  gefährdete Bruch- und Standsicherheit      ja
# 280            Hybrid-Pappel                           Sturmschaden      ja
#
#      Jahr Ortsteil
# 0    2023        K
# 1    2023        K
# 2    2023        K
# 3    2023        K
# 4    2023        K
# ..    ...      ...
# 276  2023        K
# 277  2023        K
# 278  2023        K
# 279  2023        K
# 280  2023        K
#
# [281 rows x 7 columns]

# %%
df["gefällt"].value_counts()
# Out:
# gefällt
# ja    281
# Name: count, dtype: int64

# %%
df.to_excel('2023_kreuz_cutdown.xlsx', index=False)

# %%
# 2021

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/faellliste-kreuzberg-30_06_2021.xlsx')
df
# Out:
#     notwendige Baumfällungen im Ortsteil Kreuzberg 2021 Unnamed: 1 Unnamed: 2  \
# 0                                                  NaN         NaN        NaN
# 1                                               Stand:         NaN        NaN
# 2                                  2021-06-30 00:00:00         NaN        NaN
# 3                                                  NaN         NaN        NaN
# 4                                             Standort     Baumnr.    Baumart
# ..                                                 ...         ...        ...
# 478                                                NaN         NaN        NaN
# 479                                                NaN         NaN        NaN
# 480                                                NaN         NaN        NaN
# 481                                                NaN         NaN        NaN
# 482                                               Ende         NaN        NaN
#
#                                               gefällt:           105
# 0                 Fällung verworfen, siehe Text unten:            24
# 1                                               offen:            27
# 2                                  gesamt in der Liste           156
# 3                                                  NaN           NaN
# 4    Ergebnis der Begutachtung/ Notwendigkeit der F...  2021 gefällt
# ..                                                 ...           ...
# 478                                                NaN           NaN
# 479                                                NaN           NaN
# 480                                                NaN           NaN
# 481                                                NaN           NaN
# 482                                                NaN           NaN
#
# [483 rows x 5 columns]

# %%
def clean_data_k_2021(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Kreuzberg 2021':'Standort',\
                            'Unnamed: 1':'Baumnr',\
                            'Unnamed: 2':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            105:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_k_2021(df, 2021, "K")

# %%
df
# Out:
#                             Standort Baumnr        Baumart  \
# 0    Alexandrinen/Stallschreiberstr.      9          Ahorn
# 1               Reichenberger Straße    259        Robinie
# 2                   Stresemannstraße     87          Linde
# 3                Gitschiner Straße 4     33        Platane
# 4                Gitschiner Straße 4     34        Platane
# ..                               ...    ...            ...
# 124                     Viktoriapark     41  Schwarzpappel
# 125                 Skalitzer Straße    213          Linde
# 126                 Skalitzer Straße    212          Ahorn
# 127                 Skalitzer Straße    216          Ahorn
# 128                 Skalitzer Straße    217          Ahorn
#
#                                              Fällgrund gefällt  Jahr Ortsteil
# 0    Stammschaden, gefährdete Bruch- und Standsiche...    nein  2021        K
# 1    Stamm Pilzbefall,gefährdete Bruch- und Standsi...      ja  2021        K
# 2                                          Baumaßnahme    nein  2021        K
# 3                                      Bauvorhaben BWB    nein  2021        K
# 4                                      Bauvorhaben BWB    nein  2021        K
# ..                                                 ...     ...   ...      ...
# 124                                 Kampfmittelräumung      ja  2021        K
# 125                                        Bauvorhaben      ja  2021        K
# 126                                        Bauvorhaben      ja  2021        K
# 127                                        Bauvorhaben      ja  2021        K
# 128                                        Bauvorhaben      ja  2021        K
#
# [129 rows x 7 columns]

# %%
df["gefällt"].value_counts()
# Out:
# gefällt
# ja      105
# nein     24
# Name: count, dtype: int64

# %%
# I am dropping the rows with value "nein", because those are trees which were finally not cut down
df = df[df['gefällt'] != 'nein']
df
# Out:
#                                       Standort       Baumnr           Baumart  \
# 1                         Reichenberger Straße          259           Robinie
# 7                                Cuvrystrasse             1        Kugelahorn
# 8                                Wiener Straße  o. Nr.  236             Weide
# 9                                  Böckhstraße           59  Lederhülsen-baum
# 10   Hagelberger Str. 30-34/ Großbeerenstr. 40         50\1         Haselnuss
# ..                                         ...          ...               ...
# 124                               Viktoriapark           41     Schwarzpappel
# 125                           Skalitzer Straße          213             Linde
# 126                           Skalitzer Straße          212             Ahorn
# 127                           Skalitzer Straße          216             Ahorn
# 128                           Skalitzer Straße          217             Ahorn
#
#                                              Fällgrund gefällt  Jahr Ortsteil
# 1    Stamm Pilzbefall,gefährdete Bruch- und Standsi...      ja  2021        K
# 7                           Vandalismus (Brandschaden)      ja  2021        K
# 8                Gefährdete Bruch- und Standsicherheit      ja  2021        K
# 9                Gefährdete Bruch- und Standsicherheit      ja  2021        K
# 10                                Wuchsraumregulierung      ja  2021        K
# ..                                                 ...     ...   ...      ...
# 124                                 Kampfmittelräumung      ja  2021        K
# 125                                        Bauvorhaben      ja  2021        K
# 126                                        Bauvorhaben      ja  2021        K
# 127                                        Bauvorhaben      ja  2021        K
# 128                                        Bauvorhaben      ja  2021        K
#
# [105 rows x 7 columns]

# %%
df.to_excel('2021_kreuz_cutdown.xlsx', index=False)

# %%
# 2020

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/fallliste_kb_dezember_01_2020.xlsx')
df
# Out:
#     notwendige Baumfällungen im Ortsteil Kreuzberg 2020 Unnamed: 1  \
# 0                                                  NaN         NaN
# 1                                               Stand:         NaN
# 2                                  2020-12-11 00:00:00         NaN
# 3                                                  NaN         NaN
# 4                                             Standort     Baumnr.
# ..                                                 ...         ...
# 269                            Schöneberger Str. 23-24          41
# 270                                       Viktoriapark        28/1
# 271                                   Müllenhoffstr. 7           2
# 272                                          Bethanien         186
# 273                                Gneisenaustr. 73-74          52
#
#         Unnamed: 2                                           gefällt:  \
# 0              NaN               Fällung verworfen, siehe Text unten:
# 1              NaN                                             offen:
# 2              NaN                                gesamt in der Liste
# 3              NaN                                                NaN
# 4          Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...
# ..             ...                                                ...
# 269     Vogelbeere                            absterbend/ abgestorben
# 270         Pappel                            absterbend/ abgestorben
# 271    Silberahorn              Gefährdete Bruch- und Standsicherheit
# 272  Amur-Korkbaum              Gefährdete Bruch- und Standsicherheit
# 273    Blutpflaume                            absterbend/ abgestorben
#
#                 194
# 0                 5
# 1                70
# 2               269
# 3               NaN
# 4    2020 gefällt *
# ..              ...
# 269             NaN
# 270              ja
# 271             NaN
# 272              ja
# 273             NaN
#
# [274 rows x 5 columns]

# %%
def clean_data_k_2020(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Kreuzberg 2020':'Standort',\
                            'Unnamed: 1':'Baumnr',\
                            'Unnamed: 2':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            194:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_k_2020(df, 2020, "K")

# %%
df
# Out:
#                           Standort Baumnr          Baumart  \
# 0                        Bethanien    388          Robinie
# 1    Görlitzer Ufer 2/Taborstr. 12      3            Ahorn
# 2                Kottbusser Straße     62          Kirsche
# 3                Kottbusser Straße     64          Kirsche
# 4           Möckernstraße ggü. 108     56            Linde
# ..                             ...    ...              ...
# 189              Ratiborstraße 14b     89    Säulen-Pappel
# 190                  Muskauer Str.     18         Weißdorn
# 191                Görlitzer Ufer      80  Trauben-Kirsche
# 192                   Viktoriapark   28/1           Pappel
# 193                      Bethanien    186    Amur-Korkbaum
#
#                                              Fällgrund gefällt  Jahr Ortsteil
# 0    Stammfuss Pilzbefall, gefährdete Bruch- und St...      ja  2020        K
# 1    absterbend/ abgestorben,gefährdete Bruch- und ...      ja  2020        K
# 2    absterbend/ abgestorben,gefährdete Bruch- und ...      ja  2020        K
# 3    absterbend/ abgestorben,gefährdete Bruch- und ...      ja  2020        K
# 4    Stammschaden, Neigung,gefährdete Bruch- und St...      ja  2020        K
# ..                                                 ...     ...   ...      ...
# 189              Gefährdete Bruch- und Standsicherheit      ja  2020        K
# 190                            absterbend/ abgestorben      ja  2020        K
# 191              Gefährdete Bruch- und Standsicherheit      ja  2020        K
# 192                            absterbend/ abgestorben      ja  2020        K
# 193              Gefährdete Bruch- und Standsicherheit      ja  2020        K
#
# [194 rows x 7 columns]

# %%
df.to_excel('2020_kreuz_cutdown.xlsx', index=False)

# %%
# 2019

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/kreuzberg-november-2019_1.xlsx')
df
# Out:
#      Unnamed: 0 notwendige Baumfällungen im Ortsteil Kreuzberg 2019  \
# 0           NaN                                                NaN
# 1           NaN                                             Stand:
# 2           NaN                                2019-11-20 00:00:00
# 3           NaN                                                NaN
# 4           NaN                                           Standort
# ..          ...                                                ...
# 388         NaN                                 Theodor-Wolff-Park
# 389         NaN                                 Theodor-Wolff-Park
# 390         NaN                              Rudi-Dutschke-Str. 23
# 391         NaN                                   Brachvogelstraße
# 392         NaN                                   Brachvogelstraße
#
#     Unnamed: 2       Unnamed: 3                               gefällt:  \
# 0          NaN              NaN   Fällung verworfen, siehe Text unten:
# 1          NaN              NaN                                 offen:
# 2          NaN              NaN                    gesamt in der Liste
# 3          NaN              NaN                                    NaN
# 4      Baumnr.          Baumart                              Fällgrund
# ..         ...              ...                                    ...
# 388         37          Robinie  Gefährdete Bruch- und Standsicherheit
# 389         38          Robinie  Gefährdete Bruch- und Standsicherheit
# 390          7          Robinie                absterbend/ abgestorben
# 391        108       Vogelbeere                absterbend/ abgestorben
# 392         21  Trauben-Kirsche                absterbend/ abgestorben
#
#                 231
# 0                 6
# 1               151
# 2               388
# 3               NaN
# 4    2019 gefällt *
# ..              ...
# 388             NaN
# 389             NaN
# 390             NaN
# 391             NaN
# 392             NaN
#
# [393 rows x 6 columns]

# %%
df = df.drop(["Unnamed: 0"], axis=1)
df
# Out:
#     notwendige Baumfällungen im Ortsteil Kreuzberg 2019 Unnamed: 2  \
# 0                                                  NaN         NaN
# 1                                               Stand:         NaN
# 2                                  2019-11-20 00:00:00         NaN
# 3                                                  NaN         NaN
# 4                                             Standort     Baumnr.
# ..                                                 ...         ...
# 388                                 Theodor-Wolff-Park          37
# 389                                 Theodor-Wolff-Park          38
# 390                              Rudi-Dutschke-Str. 23           7
# 391                                   Brachvogelstraße         108
# 392                                   Brachvogelstraße          21
#
#           Unnamed: 3                               gefällt:             231
# 0                NaN   Fällung verworfen, siehe Text unten:               6
# 1                NaN                                 offen:             151
# 2                NaN                    gesamt in der Liste             388
# 3                NaN                                    NaN             NaN
# 4            Baumart                              Fällgrund  2019 gefällt *
# ..               ...                                    ...             ...
# 388          Robinie  Gefährdete Bruch- und Standsicherheit             NaN
# 389          Robinie  Gefährdete Bruch- und Standsicherheit             NaN
# 390          Robinie                absterbend/ abgestorben             NaN
# 391       Vogelbeere                absterbend/ abgestorben             NaN
# 392  Trauben-Kirsche                absterbend/ abgestorben             NaN
#
# [393 rows x 5 columns]

# %%
def clean_data_k_2019(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Kreuzberg 2019':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            231:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_k_2019(df, 2019, "K")
df
# Out:
#                             Standort Baumnr    Baumart  \
# 0                   Großbeerenstraße     68      Linde
# 1                   Großbeerenstraße     75      Linde
# 2                      Möckernstraße     63      Linde
# 3    Alexandrinen/Stallschreiberstr.      4      Linde
# 4                 Alexandrinenstraße    507     Pappel
# ..                               ...    ...        ...
# 221                       Besselpark     59   Kastanie
# 222                       Besselpark     99   Kastanie
# 223                       Besselpark     87   Kastanie
# 224                      Mehringdamm     19  Hainbuche
# 225                      Mehringdamm     23  Hainbuche
#
#                                              Fällgrund gefällt  Jahr Ortsteil
# 0    Gefährdete Bruch- und Standsicherheit/ Bauvorh...      ja  2019        K
# 1    Gefährdete Bruch- und Standsicherheit/ Bauvorh...      ja  2019        K
# 2                Gefährdete Bruch- und Standsicherheit      ja  2019        K
# 3    Krone Zwiesel,gefährdete Bruch- und Standsiche...      ja  2019        K
# 4    Höhlung Stammfuss,gefährdete Bruch- und Stands...      ja  2019        K
# ..                                                 ...     ...   ...      ...
# 221                                        Bauvorhaben      ja  2019        K
# 222                            absterbend/ abgestorben      ja  2019        K
# 223              Gefährdete Bruch- und Standsicherheit      ja  2019        K
# 224                            absterbend/ abgestorben      ja  2019        K
# 225                            absterbend/ abgestorben      ja  2019        K
#
# [226 rows x 7 columns]

# %%
df.to_excel('2019_kreuz_cutdown.xlsx', index=False)

# %%
# 2018

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/kreuzberg-november-2018_1.xlsx')
df.head()
# Out:
#    Unnamed: 0 notwendige Baumfällungen im Ortsteil Kreuzberg Unnamed: 2  \
# 0         NaN                                            NaN        NaN
# 1         NaN                                         Stand:        NaN
# 2         NaN                            2018-11-02 00:00:00        NaN
# 3         NaN                                            NaN        NaN
# 4         NaN                                       Standort    Baumnr.
#
#   Unnamed: 3                              gefällt:              60
# 0        NaN  Fällung verworfen, siehe Text unten:               0
# 1        NaN                                offen:             104
# 2        NaN                   gesamt in der Liste             164
# 3        NaN                                   NaN             NaN
# 4    Baumart                             Fällgrund  2018 gefällt *

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
def clean_data_k_2018(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Kreuzberg':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            60:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_k_2018(df, 2018, "K")

# %%
df.to_excel('2018_kreuz_cutdown.xlsx', index=False)

# %%
# 2017

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/faellliste-k_dez_2017.xlsx')
df.head()
# Out:
#    Unnamed: 0 Notwendige Baumfällungen im Ortsteil Kreuzberg 2017 Unnamed: 2  \
# 0         NaN                                                NaN         NaN
# 1         NaN                                             Stand:         NaN
# 2         NaN                                2024-02-12 00:00:00         NaN
# 3         NaN                                                NaN         NaN
# 4         NaN                                                NaN         NaN
#
#   Unnamed: 3                              gefällt:  249 Unnamed: 6 Unnamed: 7  \
# 0        NaN  Fällung verworfen, siehe Text unten:   23        NaN        NaN
# 1        NaN                                offen:  112        NaN        NaN
# 2        NaN                                   NaN  384        NaN        NaN
# 3        NaN                                   NaN  NaN        NaN        NaN
# 4        NaN                                   NaN  NaN        NaN        NaN
#
#   Unnamed: 8
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
def clean_data_k_2017(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'Notwendige Baumfällungen im Ortsteil Kreuzberg 2017':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            249:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:17], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']
    df = df.reset_index(drop=True)  
    return df

# %%
df = df.drop(["Unnamed: 0", "Unnamed: 6", "Unnamed: 7", "Unnamed: 8"], axis=1)

# %%
df.head()
# Out:
#   Notwendige Baumfällungen im Ortsteil Kreuzberg 2017 Unnamed: 2 Unnamed: 3  \
# 0                                                NaN         NaN        NaN
# 1                                             Stand:         NaN        NaN
# 2                                2024-02-12 00:00:00         NaN        NaN
# 3                                                NaN         NaN        NaN
# 4                                                NaN         NaN        NaN
#
#                                gefällt:  249
# 0  Fällung verworfen, siehe Text unten:   23
# 1                                offen:  112
# 2                                   NaN  384
# 3                                   NaN  NaN
# 4                                   NaN  NaN

# %%
df = clean_data_k_2017(df, 2017, "K")

# %%
df
# Out:
#                    Standort Baumnr     Baumart  \
# 0          Brachvogelstraße      1  EBERESCHE
# 1    ETA-Hoffmann-Promenade     14       Eiche
# 2    Falckensteinstrasse 13     16       Eiche
# 3    Falckensteinstrasse 36     47       Eiche
# 4     Falckensteinstrasse 9     11       Eiche
# ..                      ...    ...         ...
# 244             Hasenheide      70    KASTANIE
# 245         Kottbusser Damm     72       Ahorn
# 246         Kottbusser Damm     73       Ahorn
# 247            Wilhelmshöhe     10       BIRKE
# 248        Kohlfurter Str.      22      Pappel
#
#                                              Fällgrund gefällt  Jahr Ortsteil
# 0    Stammschaden,gefährdete Bruch- und Standsicher...      ja  2017        K
# 1                               Baustelleneinrichtung       ja  2017        K
# 2    abgestorben,gefährdete Bruch- und Standsicherheit      ja  2017        K
# 3    abgestorben,gefährdete Bruch- und Standsicherheit      ja  2017        K
# 4    abgestorben,gefährdete Bruch- und Standsicherheit      ja  2017        K
# ..                                                 ...     ...   ...      ...
# 244                                            Umsturz      ja  2017        K
# 245                                    Bauvorhaben BVB      ja  2017        K
# 246                                    Bauvorhaben BVB      ja  2017        K
# 247  absterbend,abgestorben,gefährdete Bruch- und S...      ja  2017        K
# 248  Wurzelanhebungen,gefährdete Bruch- und Standsi...      ja  2017        K
#
# [249 rows x 7 columns]

# %%
df.to_excel('2017_kreuz_cutdown.xlsx', index=False)

# %% [markdown]
# ### Trees in subdistrict Friedrichshain

# %%
# 2022

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/2022_faellliste_friedrichshain.xlsx')

# %%
df.head()
# Out:
#   notwendige Baumfällungen im Ortsteil Friedrichshain 2022 Unnamed: 1  \
# 0                                                NaN              NaN
# 1                                             Stand:              NaN
# 2                                2023-01-01 00:00:00              NaN
# 3                                                NaN              NaN
# 4                                           Standort          Baumnr.
#
#   Unnamed: 2                                         Unnamed: 3    Unnamed: 4
# 0        NaN                                                NaN           NaN
# 1        NaN                                                NaN           NaN
# 2        NaN                                                NaN           NaN
# 3        NaN                                                NaN           NaN
# 4    Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...  2022 gefällt

# %%
def clean_data_f_22(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2022':'Standort',\
                            'Unnamed: 1':'Baumnr',\
                            'Unnamed: 2':'Baumart', \
                            'Unnamed: 3':'Fällgrund',\
                            'Unnamed: 4':'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_f_22(df, 2022, "F")

# %%
df.head()
# Out:
#               Standort Baumnr                 Baumart  \
# 0    Alt-Stralau 20-29     17           Silber-Pappel
# 1       Alt-Stralau 34     16  Chinesische Wild-Birne
# 2       Alt-Stralau 34     50                 Robinie
# 3    Alt-Stralau 40-43    N 5                   Weide
# 4  Am Containerbahnhof     13               Sal-Weide
#
#                                            Fällgrund gefällt  Jahr Ortsteil
# 0              gefährdete Bruch- und Standsicherheit      ja  2022        F
# 1                            absterbend/ abgestorben      ja  2022        F
# 2              gefährdete Bruch- und Standsicherheit      ja  2022        F
# 3              gefährdete Bruch- und Standsicherheit      ja  2022        F
# 4  Wuchsraumregulierung (nur bei konkurrierenden ...      ja  2022        F

# %%
df.to_excel('2022_fried_cutdown.xlsx', index=False)

# %%
# 2023

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/faellliste-fhain-stand-311223.xlsx')

# %%
df.head(7)
# Out:
#   Unnamed: 0 notwendige Baumfällungen im Ortsteil Friedrichshain 2023  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2        NaN                                                NaN
# 3        NaN                                                NaN
# 4          .                                           Standort
# 5        NaN                           Alt-Stralau 10-12, Spiel
# 6        NaN                    Alt-Stralau 32A, Tunnelstr. 1-4
#
#   Unnamed: 2 Unnamed: 3                                         Unnamed: 4  \
# 0        NaN        NaN                                                NaN
# 1        NaN        NaN                                                NaN
# 2        NaN        NaN                                                NaN
# 3        NaN        NaN                                                NaN
# 4    Baumnr.    Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...
# 5       23/1     Pappel                               Wuchsraumregulierung
# 6        1/1      Weide                            absterbend/ abgestorben
#
#      Unnamed: 5
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4  2023 gefällt
# 5            ja
# 6            ja

# %%
df = df.drop(["Unnamed: 0"], axis=1)
df.head()
# Out:
#   notwendige Baumfällungen im Ortsteil Friedrichshain 2023 Unnamed: 2  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                           Standort          Baumnr.
#
#   Unnamed: 3                                         Unnamed: 4    Unnamed: 5
# 0        NaN                                                NaN           NaN
# 1        NaN                                                NaN           NaN
# 2        NaN                                                NaN           NaN
# 3        NaN                                                NaN           NaN
# 4    Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...  2023 gefällt

# %%
def clean_data_f_23(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2023':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'Unnamed: 4':'Fällgrund',\
                            'Unnamed: 5':'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)
     
    # Deleting rows with null values in a chosen column, because we consider only cut down trees
    df = df.dropna(subset=['gefällt'])  
    df = df.reset_index(drop=True)  
    return df

# %%
df = clean_data_f_23(df, 2023, "F")
df.head()
# Out:
#                           Standort Baumnr                    Baumart  \
# 0         Alt-Stralau 10-12, Spiel   23/1                     Pappel
# 1  Alt-Stralau 32A, Tunnelstr. 1-4    1/1                      Weide
# 2  Alt-Stralau 32A, Tunnelstr. 1-4   69/1              Silber-Pappel
# 3                Alt-Stralau 40-43     13  Hänge-Weide, Trauer-Weide
# 4                Alt-Stralau 40-43   13/1                Grau-Pappel
#
#                                Fällgrund gefällt  Jahr Ortsteil
# 0                   Wuchsraumregulierung      ja  2023        F
# 1                absterbend/ abgestorben      ja  2023        F
# 2  gefährdete Bruch- und Standsicherheit      ja  2023        F
# 3  gefährdete Bruch- und Standsicherheit      ja  2023        F
# 4  gefährdete Bruch- und Standsicherheit      ja  2023        F

# %%
df.to_excel('2023_fried_cutdown.xlsx', index=False)

# %%
# 2021

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/faellliste-f-hain-_16_11_2021.xlsx')

# %%
df.head()
# Out:
#   Unnamed: 0 notwendige Baumfällungen im Ortsteil Friedrichshain 2021  \
# 0        NaN                                                NaN
# 1        NaN                                             Stand:
# 2        NaN                                2021-11-17 00:00:00
# 3        NaN                                                NaN
# 4          .                                           Standort
#
#   Unnamed: 2 Unnamed: 3                                           gefällt:  \
# 0        NaN        NaN               Fällung verworfen, siehe Text unten:
# 1        NaN        NaN                                             offen:
# 2        NaN        NaN                                gesamt in der Liste
# 3        NaN        NaN                                                NaN
# 4    Baumnr.    Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...
#
#             320
# 0            14
# 1            78
# 2           412
# 3           NaN
# 4  2021 gefällt

# %%
df = df.drop(["Unnamed: 0"], axis=1)
df.head()
# Out:
#   notwendige Baumfällungen im Ortsteil Friedrichshain 2021 Unnamed: 2  \
# 0                                                NaN              NaN
# 1                                             Stand:              NaN
# 2                                2021-11-17 00:00:00              NaN
# 3                                                NaN              NaN
# 4                                           Standort          Baumnr.
#
#   Unnamed: 3                                           gefällt:           320
# 0        NaN               Fällung verworfen, siehe Text unten:            14
# 1        NaN                                             offen:            78
# 2        NaN                                gesamt in der Liste           412
# 3        NaN                                                NaN           NaN
# 4    Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...  2021 gefällt

# %%
def clean_data_f_2021(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2021':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            320:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)   
    # Deleting rows with null values in a chosen column
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']      
    return df

# %%
df = clean_data_f_2021(df, 2021, "F")

# %%
df
# Out:
#                              Standort Baumnr         Baumart  \
# 5                    Lehmbruckstr. 13      9       Eberesche
# 6                   Dirschauer Straße     42       Mehlbeere
# 7            Volkspark Friedrichshain   5013      Feld-Ahorn
# 8            Volkspark Friedrichshain   5054           Birke
# 9            Volkspark Friedrichshain   5478         Robinie
# ..                                ...    ...             ...
# 396           Pettenkoferstraße 20-24     25         Robinie
# 397           Pettenkoferstraße 20-24     29         Robinie
# 398                 Hausburgstraße 20     52  Echter Rotdorn
# 399                 Hausburgstraße 21     54        Weißdorn
# 416  Weinstr. 2, Jugendverkehrsschule     49          Pappel
#
#                                  Fällgrund gefällt  Jahr Ortsteil
# 5                  absterbend/ abgestorben      ja  2021        F
# 6                  absterbend/ abgestorben      ja  2021        F
# 7                  absterbend/ abgestorben      ja  2021        F
# 8    Gefährdete Bruch- und Standsicherheit      ja  2021        F
# 9    Gefährdete Bruch- und Standsicherheit      ja  2021        F
# ..                                     ...     ...   ...      ...
# 396  Gefährdete Bruch- und Standsicherheit      ja  2021        F
# 397  Gefährdete Bruch- und Standsicherheit      ja  2021        F
# 398  Gefährdete Bruch- und Standsicherheit      ja  2021        F
# 399  Gefährdete Bruch- und Standsicherheit      ja  2021        F
# 416                absterbend/ abgestorben      ja  2021        F
#
# [320 rows x 7 columns]

# %%
df.to_excel('2021_fried_cutdown.xlsx', index=False)

# %%
# 2020

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/fallliste_fh_dezember_01_2020.xlsx')

# %%
df.head()
# Out:
#   notwendige Baumfällungen im Ortsteil Friedrichshain 2020 Unnamed: 1  \
# 0                                                NaN              NaN
# 1                                             Stand:              NaN
# 2                                2020-12-11 00:00:00              NaN
# 3                                                NaN              NaN
# 4                                           Standort          Baumnr.
#
#   Unnamed: 2                                           gefällt:           373
# 0        NaN               Fällung verworfen, siehe Text unten:            14
# 1        NaN                                             offen:           108
# 2        NaN                                gesamt in der Liste           495
# 3        NaN                                                NaN           NaN
# 4    Baumart  Ergebnis der Begutachtung/ Notwendigkeit der F...  2020 gefällt

# %%
def clean_data_f_2020(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2020':'Standort',\
                            'Unnamed: 1':'Baumnr',\
                            'Unnamed: 2':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            373:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)   
    # Deleting rows with null values in a chosen column
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']      
    return df

# %%
df = clean_data_f_2020(df, 2020, "F")

# %%
df["gefällt"].value_counts()
# Out:
# gefällt
# ja    390
# 6       1
# Name: count, dtype: int64

# %%
# Value 6 is not defined, we dont know if the tree was cut down or not. 
# This is why I decide to drop this row. 
df = df[df['gefällt'] != 6]

# %%
df.to_excel('2020_fried_cutdown.xlsx', index=False)

# %%
# 2019

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/friedrichshain-november-2019_1.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0 notwendige Baumfällungen im Ortsteil Friedrichshain 2019  \
# 0         NaN                                                NaN
# 1         NaN                                             Stand:
# 2         NaN                                2019-11-20 00:00:00
# 3         NaN                                                NaN
# 4         NaN                                           Standort
#
#   Unnamed: 2 Unnamed: 3                              gefällt:             163
# 0        NaN        NaN  Fällung verworfen, siehe Text unten:              10
# 1        NaN        NaN                                offen:             261
# 2        NaN        NaN                   gesamt in der Liste             434
# 3        NaN        NaN                                   NaN             NaN
# 4    Baumnr.    Baumart                             Fällgrund  2019 gefällt *

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
def clean_data_f_2019(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2019':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            163:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)   
    # Deleting rows with null values in a chosen column
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']      
    return df

# %%
df = clean_data_f_2019(df, 2019, "F")

# %%
df
# Out:
#                                               Standort Baumnr  \
# 14                                Markgrafendamm 20-22     10
# 15                                   Markgrafendamm 24      3
# 25                                 Karl-Marx-Allee 70a    306
# 26   Langenbeckstraße (hinter Sportplatz Virchowstr...     27
# 33                       Grünfläche Tunnelstraße 13-24  10090
# ..                                                 ...    ...
# 334                                  Kochhannstraße 39   27/1
# 335                      Kochhannstraße vor Grünanlage   28/3
# 336                                  Hausburgstraße 18     66
# 337            Volkspark Friedrichshain, Mächenbrunnen  358/3
# 338                                      Mainzerstraße     31
#
#               Baumart                              Fällgrund gefällt  Jahr  \
# 14              Ahorn  Gefährdete Bruch- und Standsicherheit      ja  2019
# 15         Götterbaum              verursacht Gebäudeschäden      ja  2019
# 25              Linde  Baummaßnahme Wasserbetriebe, 01.12.17      ja  2019
# 26             Pappel   Baumaßnahme Sportplatz Virchowstraße      ja  2019
# 33              Linde  Gefährdete Bruch- und Standsicherheit      ja  2019
# ..                ...                                    ...     ...   ...
# 334  Säulen-Eberesche                Absterbend/ abgestorben      ja  2019
# 335  Säulen-Eberesche                Absterbend/ abgestorben      ja  2019
# 336      Winterlinde                 Absterbend/ abgestorben      ja  2019
# 337             Linde                Absterbend/ abgestorben      ja  2019
# 338          Weißdorn                Absterbend/ abgestorben      ja  2019
#
#     Ortsteil
# 14         F
# 15         F
# 25         F
# 26         F
# 33         F
# ..       ...
# 334        F
# 335        F
# 336        F
# 337        F
# 338        F
#
# [163 rows x 7 columns]

# %%
df.to_excel('2019_fried_cutdown.xlsx', index=False)

# %%
# 2018

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/faellliste-friedrichshain-dezember-2018_1.xlsx')
df.head()
# Out:
#    Unnamed: 0 notwendige Baumfällungen im Ortsteil Friedrichshain 2018  \
# 0         NaN                                                NaN
# 1         NaN                                             Stand:
# 2         NaN                                2019-01-03 00:00:00
# 3         NaN                                                NaN
# 4         NaN                                           Standort
#
#   Unnamed: 2 Unnamed: 3                              gefällt:             168
# 0        NaN        NaN  Fällung verworfen, siehe Text unten:               4
# 1        NaN        NaN                                offen:              32
# 2        NaN        NaN                   gesamt in der Liste             204
# 3        NaN        NaN                                   NaN             NaN
# 4    Baumnr.    Baumart                             Fällgrund  2018 gefällt *

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
def clean_data_f_2018(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2018':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            168:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)   
    # Deleting rows with null values in a chosen column
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']      
    return df

# %%
df = clean_data_f_2018(df, 2018, "F")

# %%
df["gefällt"].value_counts()
# Out:
# gefällt
# ja    168
# Name: count, dtype: int64

# %%
df.to_excel('2018_fried_cutdown.xlsx', index=False)

# %%
# 2017

# %%
df = pd.read_excel('../Trees/Fried_Kreuz_Faellung/friedrichshain-dezember-2017_2.xlsx')
df.head()
# Out:
#    Unnamed: 0 notwendige Baumfällungen im Ortsteil Friedrichshain 2017  \
# 0         NaN                                                NaN
# 1         NaN                                             Stand:
# 2         NaN                                2017-12-19 00:00:00
# 3         NaN                                                NaN
# 4         NaN                                           Standort
#
#   Unnamed: 2 Unnamed: 3                              gefällt:             143
# 0        NaN        NaN  Fällung verworfen, siehe Text unten:               2
# 1        NaN        NaN                                offen:              91
# 2        NaN        NaN                   gesamt in der Liste             236
# 3        NaN        NaN                                   NaN             NaN
# 4    Baumnr.    Baumart                             Fällgrund  2017 gefällt *

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
def clean_data_f_2017(df, year, subdistrict):
    # Function to clean data
    
    df = df.rename(columns={'notwendige Baumfällungen im Ortsteil Friedrichshain 2017':'Standort',\
                            'Unnamed: 2':'Baumnr',\
                            'Unnamed: 3':'Baumart', \
                            'gefällt:':'Fällgrund',\
                            143:'gefällt'})
    df["Jahr"] = year
    df["Ortsteil"] = subdistrict
    df = df.drop(df.index[0:5], axis=0)   
    # Deleting rows with null values in a chosen column
    df = df.dropna(subset=['gefällt'])  
    # I am dropping the rows with value "nein", because those are trees which were finally not cut down
    df = df[df['gefällt'] != 'nein']      
    return df

# %%
df = clean_data_f_2017(df, 2017, "F")

# %%
df.to_excel('2017_fried_cutdown.xlsx', index=False)
